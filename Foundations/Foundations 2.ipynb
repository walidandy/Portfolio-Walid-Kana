# %% [markdown]
# **No olvidarse del Area Efectiva, cuando se tengan excentricidades**
#
# *Si:*
# $$e>\frac{B}{6}$$
# $$q_{min}=0$$
#
# *Donde e: excentricidad en cualquiera de los sentidos (x o y)*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Cimentacion Continua**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Presion de contacto:
# $$p=p_o(1+\frac{3*e*x}{a^2})$$
# $$p_o=P/A$$
#
# *Nota: Considerar que L es un ancho unitario, por lo tanto:*
#
# $$R=\sum{P}$$
# $$e=\frac{\sum{M}}{R}$$
# $$p_o=\frac{R}{B}$$
# $$p=p_o(1+\frac{3*e*x}{a^2})$$
#
# *Nota: Los momentos se toman respecto al centroide del contacto entre la zapata y el suelo*

# %% [markdown]
# **Cimentacion Aislada**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# *Nota: Calcular todos los valores y compararlos **Cuidado !***

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Presion de contacto:
# $$p=p_o(1 \pm \frac{3*e*x}{a^2} \pm \frac{3*e*y}{b^2})$$
# $$p_o=\frac{P}{A}$$
#
# *Nota: Considerar que L es un ancho unitario, por lo tanto:*
#
# $$R=\sum{P}$$
# $$e=\frac{\sum{M}}{R}$$
# $$p_o=\frac{R}{BL}$$
# $$p=p_o(1 \pm \frac{3*e*x}{a^2} \pm \frac{3*e*y}{b^2})$$
#
# *Nota: Los momentos se toman respecto al centroide del contacto entre la zapata y el suelo*

# %% [markdown]
# **Cimentacion Combinada**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***Nota : Comparar todos los esfuerzos Ojo***

# %% [markdown]
# Presion de contacto:
# $$p=p_o(1 \pm \frac{3*e*x}{a^2})$$
# $$p_o=\frac{P}{A}$$
#
# *Nota: Considerar que L es un ancho unitario, por lo tanto:*
#
# $$R=\sum{P}$$
# $$e=\frac{\sum{M}}{R}$$
# $$p_o=\frac{R}{BL}$$
# $$p=p_o(1 \pm \frac{3*e*x}{a^2})$$
#
# *Nota 1: Los momentos se toman respecto al centroide del contacto entre la zapata y el suelo*
#
# *Nota 2: La excentricidad en y es menor porque la cantidad de momentos en x generados por el relleno es muy pequeña y no genera una excentricidad considerable, considerando ademas que las columnas estan alineadas en el centroide x de la cimentacion*

# %% [markdown]
# **Losa de Cimentacion**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Presion de contacto:
# $$p=p_o(1 \pm \frac{3*e*x}{a^2} \pm \frac{3*e*y}{b^2})$$
# $$p_o=\frac{P}{A}$$
#
# *Nota: Considerar que L es un ancho unitario, por lo tanto:*
#
# $$R=\sum{P}$$
# $$e=\frac{\sum{M}}{R}$$
# $$p_o=\frac{R}{BL}$$
# $$p=p_o(1 \pm \frac{3*e*x}{a^2} \pm \frac{3*e*y}{b^2})$$
#
# *Nota: Los momentos se toman respecto al centroide del contacto entre la zapata y el suelo*
#
# *Nota: El a para el B y b para L*

# %% [markdown]
# **Factores de Correccion**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Simplemente hallar el volumen, determinando el area:
#
# $$A=\frac{ (\sum{p_{max}+p_{min}}) L}{2}$$
# $$V=A(B)$$
# $$V=p=A(B)$$

# %% [markdown]
# - w_min=promedio de a y c
#
# - w_max=promedio de b y d
#
# Debemos corregir estos esfuerzos:
#
# $$K=\frac{\sum{P}}{p}$$
#
# Donde p es la respuesta del suelo
#
# - w_min_cor=promedio de a y c * K
#
# - w_max_cor=promedio de b y d * K
#
# *Nota: El analisis es por franja*

# %% [markdown]
# **No olvidarse del Area Efectiva, cuando se tengan excentricidades**

# %% [markdown]
# ---

# %% [markdown]
# **Viga Infinita (Cimentacion Corrida)**

# %%
from sympy import *
import numpy as np
ko=1 # Modulo de balasto
B=1 # cm Ancho de la cimentacion
h=1 # cm Altura de la cimentacion
E=1 # kgf/cm2 Modulo de elasticidad de la cimentacion
I=B*h**3/12 # cm4 Momento de inercia de la cimentacion
P=1 # tnf Carga aplicada
M=1 # tnf-m Momento aplicado
x=1 # adimensional
beta=((ko*B)/(4*E*I))**(1/4)*100 # 1/m Cuidado !
l_beta=1/beta # m Longitud caracteristica
Mp=P/(4*beta)*np.exp(-beta*x)*(np.cos(beta*x)-np.sin(beta*x)) # tnf-m Momento de reaccion
Mm=M/2*np.exp(-beta*x)*np.cos(beta*x) # tnf-m Momento de reaccion

# %% [markdown]
# **Viga Semi Infinita**

# %%
from sympy import *
import numpy as np
ko=1 # Modulo de balasto
B=1 # cm Ancho de la cimentacion
h=1 # cm Altura de la cimentacion
E=1 # kgf/cm2 Modulo de elasticidad de la cimentacion
I=B*h**3/12 # cm4 Momento de inercia de la cimentacion
P=1 # tnf Carga aplicada
M=1 # tnf-m Momento aplicado
x=1 # adimensional
beta=((ko*B)/(4*E*I))**(1/4)*100 # 1/m Cuidado !
l_beta=1/beta # m Longitud caracteristica
Mp=P/beta*np.exp(-beta*x)*np.sin(beta*x) # tnf-m Momento de reaccion
Mm=M*np.exp(-beta*x)*(np.cos(beta*x)+np.sin(beta*x)) # tnf-m Momento de reaccion

# %% [markdown]
# **Viga Finita**

# %%
from sympy import *
import numpy as np
import plotly.graph_objects as go
ko=10 # Modulo de balasto
B=60 # cm Ancho de la cimentacion
h=20 # cm Altura de la cimentacion
E=15000*210**.5 # kgf/cm2 Modulo de elasticidad de la cimentacion
I=B*h**3/12 # cm4 Momento de inercia de la cimentacion
P=15 # tnf Carga aplicada
M=6 # tnf-m Momento aplicado
x=np.linspace(0,2*np.pi,100) # adimensional
beta=((ko*B)/(4*E*I))**(1/4)*100 # 1/m Cuidado !
l_beta=1/beta # m Longitud caracteristica
Mp=P/(4*beta)*np.exp(-beta*x)*(np.cos(beta*x)-np.sin(beta*x)) # tnf-m Momento de reaccion
Mm=M/2*np.exp(-beta*x)*np.cos(beta*x) # tnf-m Momento de reaccion
fig=go.Figure()
fig.add_trace(go.Scatter(x=x,y=Mp,name='Mp'))
fig.add_trace(go.Scatter(x=x,y=Mm,name='Mm'))
fig.show()

# %%
beta
# Out:
# 1.1460606210895123

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Gracias mi Dios ! Amen ...**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
